# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/AmoDinho/DeepLearning-Masters/blob/master/ImageAI_Experiment1.ipynb)

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
# !pip install fastai
# Out:
# ...
#     100% |████████████████████████████████| 122kB 3.5MB/s
# ...
#     100% |████████████████████████████████| 3.6MB 7.0MB/s
# ...
#     100% |████████████████████████████████| 61kB 16.8MB/s
# ...
#     100% |████████████████████████████████| 496.4MB 24kB/s
# ...
#     100% |████████████████████████████████| 2.2MB 891kB/s
# ...
#     100% |████████████████████████████████| 51kB 21.7MB/s
# ...
#     100% |████████████████████████████████| 1.5MB 4.2MB/s
# ...
#     100% |████████████████████████████████| 184kB 30.3MB/s
# ...
#     100% |████████████████████████████████| 112kB 29.8MB/s
# ...
#     100% |████████████████████████████████| 112kB 30.2MB/s
# ...
#     100% |████████████████████████████████| 901kB 3.3MB/s
# ...
#     100% |████████████████████████████████| 71kB 23.7MB/s
# ...
#     100% |████████████████████████████████| 92kB 27.8MB/s
# ...
#     100% |████████████████████████████████| 11.6MB 2.4MB/s
# ...
#     100% |████████████████████████████████| 1.5MB 5.7MB/s
# ...
#     100% |████████████████████████████████| 15.8MB 2.3MB/s
# ...

# %%
# !pip install https://github.com/OlafenwaMoses/ImageAI/releases/download/2.0.2/imageai-2.0.2-py3-none-any.whl

# %%
 # !wget https://github.com/OlafenwaMoses/ImageAI/releases/download/1.0/resnet50_coco_best_v2.0.1.h5
# Out:
# Redirecting output to ‘wget-log.8’.

# %%
# !wget https://media.wired.com/photos/59095e3d76f462691f012c3e/master/pass/MadMaxFuryRoad-247-ft.jpg
# Out:
# Redirecting output to ‘wget-log.10’.

# %%
os.getcwd()
# Out:
# '/content'

# %%
PATH='/content'

# %%
PATH_IMG='/content/imagenew.jpg'

# %%
# !wget https://cdn.teslarati.com/wp-content/uploads/2017/11/Roadster_Front_34_1-e1512593855725.jpg
# Out:
# Redirecting output to ‘wget-log.9’.

# %%
# %ls {PATH}
# Out:
# imagenew.jpg                            sample_data/
# model/                                  wget-log
# resnet50_coco_best_v2.0.1.h5            wget-log.1
# resnet50_coco_best_v2.0.1.h5.1          wget-log.2
# Roadster_Front_34_1-e1512593855725.jpg

# %%
from imageai.Detection import ObjectDetection
import os

execution_path = os.getcwd()

detector = ObjectDetection()
detector.setModelTypeAsRetinaNet()
detector.setModelPath(os.path.join(execution_path,"resnet50_coco_best_v2.0.1.h5"))
detector.loadModel()
detections = detector.detectObjectsFromImage(input_image=os.path.join(execution_path , "MadMaxFuryRoad-247-ft.jpg"), output_image_path=os.path.join(execution_path , "madmax.jpg"))

for eachObject in detections:
    print(eachObject["name"], " : ", eachObject["percentage_probability"])
# Out:
# person  :  60.606878995895386
# person  :  63.70214223861694
# person  :  55.54365515708923
# person  :  63.13071250915527
# person  :  79.1204035282135
# person  :  63.23572397232056
# person  :  61.4205002784729
# person  :  80.71891069412231
# person  :  52.70447134971619
# person  :  56.511735916137695
# motorcycle  :  73.8260269165039
# truck  :  64.23994898796082
# car  :  59.66187119483948
# person  :  52.47039794921875
# car  :  96.09348773956299

# %%
image = open(f'{PATH}/imagenew.jpg')

# %%
from fastai.plots import *

# %%
car_image = plt.imread(f'{PATH_IMG}')
plt.imshow(car_image)
plt.axis('off')
plt.show()

# %%
madmax = plt.imread(f'{PATH}/madmax.jpg')
plt.imshow(madmax)
plt.axis('off')
plt.figure(figsize=(20,12))
plt.show()
